# %%
from cdt import *
from initialization import make_flat_spacetime
from vizualization import vizualize_space_time_2d
import matplotlib.pyplot as plt
import numpy as np
import space_time
import time
import pylab as pl
from IPython import display

# %%
# Test 1, visualize a small space-time after one move
st = space_time.space_time()

st.generate_flat(10, 10)

for i in range(100):
    
    st.move(st.get_random_node())
    st.inverse_move(st.get_random_node())
    plt.imshow(st.adjacency())
#     vizualize_space_time_2d(st)
    display.clear_output(wait=True)
    display.display(pl.gcf())
plt.close()
# Out:
# blipity
# 0
# blopity
# the length of the nodes list is32
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-78fa5db75bee> in <module>
#       9 #     st.move(st.get_random_node())
#      10     st.inverse_move(st.get_random_node())
# ---> 11     plt.imshow(st.adjacency())
#      12 #     vizualize_space_time_2d(st)
#      13     display.clear_output(wait=True)
#
# ~/Documents/CDT/python/space_time.py in adjacency(self)
#     203         print("the length of the nodes list is" + str(len(self.nodes)))
#     204         for i, n in enumerate(self.nodes.values()):
# --> 205             m[row_idex_dict[n.index], row_idex_dict[n.right]] = 1.0
#     206             m[row_idex_dict[n.index], row_idex_dict[n.left]] = 1.0
#     207             for f in n.future:
#
# KeyError: 0

# %%
st = space_time.space_time()
st.generate_flat(16, 32)
st.inverse_move(st.nodes[30])
st.move(st.get_random_node())
vizualize_space_time_2d(st)
